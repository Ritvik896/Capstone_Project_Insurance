# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
c_f = pd.read_csv("C:\\Users\\RITVISINGH\\Desktop\\Capstone1_Car Insurance\\InsuranceData\\csv\\Car features.csv")
p_f = pd.read_csv("C:\\Users\\RITVISINGH\\Desktop\\Capstone1_Car Insurance\\InsuranceData\\csv\\Policy features.csv")
i_c = pd.read_csv("C:\\Users\\RITVISINGH\\Desktop\\Capstone1_Car Insurance\\InsuranceData\\csv\\Insurance claim.csv")

# %%
c_f.head()
# Out:
#   policy_id  make segment model fuel_type     max_torque         max_power  \
# 0   ID00001     1       A    M1       CNG   60Nm@3500rpm  40.36bhp@6000rpm
# 1   ID00002     1       A    M1       CNG   60Nm@3500rpm  40.36bhp@6000rpm
# 2   ID00003     1       A    M1       CNG   60Nm@3500rpm  40.36bhp@6000rpm
# 3   ID00004     1      C1    M2    Petrol  113Nm@4400rpm  88.50bhp@6000rpm
# 4   ID00005     2       A    M3    Petrol   91Nm@4250rpm  67.06bhp@5500rpm
#
#           engine_type  airbags is_esc  ... is_rear_window_defogger  \
# 0   F8D Petrol Engine      2.0     No  ...                      No
# 1   F8D Petrol Engine      2.0     No  ...                      No
# 2   F8D Petrol Engine      2.0     No  ...                      No
# 3  1.2 L K12N Dualjet      2.0    Yes  ...                     Yes
# 4             1.0 SCe      2.0     No  ...                      No
#
#   is_brake_assist is_power_door_locks is_central_locking is_power_steering  \
# 0              No                  No                 No               Yes
# 1              No                  No                 No               Yes
# 2              No                  No                 No               Yes
# 3             Yes                 Yes                Yes               Yes
# 4              No                 Yes                Yes               Yes
#
#    is_driver_seat_height_adjustable  is_day_night_rear_view_mirror is_ecw  \
# 0                                No                             No     No
# 1                                No                             No     No
# 2                                No                             No     No
# 3                               Yes                            Yes    Yes
# 4                                No                            Yes    Yes
#
#    is_speed_alert ncap_rating
# 0             Yes           0
# 1             Yes           0
# 2             Yes           0
# 3             Yes           2
# 4             Yes           2
#
# [5 rows x 38 columns]

# %%
p_f.head()
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874        0.05             0.644231           C1
# 1   ID00002       0.672619        0.02             0.375000           C2
# 2   ID00003       0.841110        0.02             0.384615           C3
# 3   ID00004       0.900277        0.11             0.432692           C4
# 4   ID00005       0.596403        0.11             0.634615           C5
#
#    population_density
# 0              4990.0
# 1             27003.0
# 2              4076.0
# 3             21622.0
# 4             34738.0

# %%
i_c.head()
# Out:
#   policy_id  is_claim
# 0   ID00001         0
# 1   ID00002         0
# 2   ID00003         0
# 3   ID00004         0
# 4   ID00005         0

# %%
merged_data = pd.merge(c_f,p_f,on='policy_id',how='inner')

# %%
merged_data.head()
# Out:
#   policy_id  make segment model fuel_type     max_torque         max_power  \
# 0   ID00001     1       A    M1       CNG   60Nm@3500rpm  40.36bhp@6000rpm
# 1   ID00002     1       A    M1       CNG   60Nm@3500rpm  40.36bhp@6000rpm
# 2   ID00003     1       A    M1       CNG   60Nm@3500rpm  40.36bhp@6000rpm
# 3   ID00004     1      C1    M2    Petrol  113Nm@4400rpm  88.50bhp@6000rpm
# 4   ID00005     2       A    M3    Petrol   91Nm@4250rpm  67.06bhp@5500rpm
#
#           engine_type  airbags is_esc  ... is_driver_seat_height_adjustable  \
# 0   F8D Petrol Engine      2.0     No  ...                               No
# 1   F8D Petrol Engine      2.0     No  ...                               No
# 2   F8D Petrol Engine      2.0     No  ...                               No
# 3  1.2 L K12N Dualjet      2.0    Yes  ...                              Yes
# 4             1.0 SCe      2.0     No  ...                               No
#
#   is_day_night_rear_view_mirror is_ecw is_speed_alert ncap_rating  \
# 0                            No     No            Yes           0
# 1                            No     No            Yes           0
# 2                            No     No            Yes           0
# 3                           Yes    Yes            Yes           2
# 4                           Yes    Yes            Yes           2
#
#    policy_tenure  age_of_car age_of_policyholder  area_cluster  \
# 0       0.515874        0.05            0.644231            C1
# 1       0.672619        0.02            0.375000            C2
# 2       0.841110        0.02            0.384615            C3
# 3       0.900277        0.11            0.432692            C4
# 4       0.596403        0.11            0.634615            C5
#
#   population_density
# 0             4990.0
# 1            27003.0
# 2             4076.0
# 3            21622.0
# 4            34738.0
#
# [5 rows x 43 columns]

# %%
final_data = pd.merge(merged_data,i_c,on='policy_id',how='inner')

# %% [markdown]
# STRUCTURE OF DATASET

# %% [markdown]
# 1) First 5 rows

# %%
final_data.head()
# Out:
#   policy_id  make segment model fuel_type     max_torque         max_power  \
# 0   ID00001     1       A    M1       CNG   60Nm@3500rpm  40.36bhp@6000rpm
# 1   ID00002     1       A    M1       CNG   60Nm@3500rpm  40.36bhp@6000rpm
# 2   ID00003     1       A    M1       CNG   60Nm@3500rpm  40.36bhp@6000rpm
# 3   ID00004     1      C1    M2    Petrol  113Nm@4400rpm  88.50bhp@6000rpm
# 4   ID00005     2       A    M3    Petrol   91Nm@4250rpm  67.06bhp@5500rpm
#
#           engine_type  airbags is_esc  ... is_day_night_rear_view_mirror  \
# 0   F8D Petrol Engine      2.0     No  ...                            No
# 1   F8D Petrol Engine      2.0     No  ...                            No
# 2   F8D Petrol Engine      2.0     No  ...                            No
# 3  1.2 L K12N Dualjet      2.0    Yes  ...                           Yes
# 4             1.0 SCe      2.0     No  ...                           Yes
#
#   is_ecw is_speed_alert ncap_rating policy_tenure  age_of_car  \
# 0     No            Yes           0      0.515874        0.05
# 1     No            Yes           0      0.672619        0.02
# 2     No            Yes           0      0.841110        0.02
# 3    Yes            Yes           2      0.900277        0.11
# 4    Yes            Yes           2      0.596403        0.11
#
#    age_of_policyholder area_cluster  population_density is_claim
# 0             0.644231           C1              4990.0        0
# 1             0.375000           C2             27003.0        0
# 2             0.384615           C3              4076.0        0
# 3             0.432692           C4             21622.0        0
# 4             0.634615           C5             34738.0        0
#
# [5 rows x 44 columns]

# %% [markdown]
# 2) Summary Statistics

# %%
round(final_data.describe(),2).T
# Out:
#                        count      mean       std      min      25%      50%  \
# make                 58515.0      1.76      1.14     1.00     1.00     1.00
# airbags              58506.0      3.14      1.83     1.00     2.00     2.00
# displacement         58508.0   1162.29    266.30   796.00   796.00  1197.00
# cylinder             58508.0      3.63      0.48     3.00     3.00     4.00
# gear_box             58515.0      5.25      0.43     5.00     5.00     5.00
# turning_radius       58515.0      4.85      0.23     4.50     4.60     4.80
# length               58515.0   3850.38    311.43  3445.00  3445.00  3845.00
# width                58515.0   1672.21    112.09  1475.00  1515.00  1735.00
# height               58515.0   1553.32     79.62  1475.00  1475.00  1530.00
# gross_weight         58515.0   1385.23    212.39  1051.00  1185.00  1335.00
# ncap_rating          58515.0      1.76      1.39     0.00     0.00     2.00
# policy_tenure        58495.0      0.61      0.41     0.00     0.21     0.57
# age_of_car           58510.0      0.07      0.06     0.00     0.02     0.06
# age_of_policyholder  58508.0      0.47      0.12     0.29     0.37     0.45
# population_density   58503.0  18828.56  17661.06   290.00  6112.00  8794.00
# is_claim             58515.0      0.06      0.24     0.00     0.00     0.00
#
#                           75%      max
# make                     3.00      5.0
# airbags                  6.00      6.0
# displacement          1493.00   1498.0
# cylinder                 4.00      4.0
# gear_box                 5.00      6.0
# turning_radius           5.00      5.2
# length                3995.00   4300.0
# width                 1755.00   1811.0
# height                1635.00   1825.0
# gross_weight          1510.00   1720.0
# ncap_rating              3.00      5.0
# policy_tenure            1.04      1.4
# age_of_car               0.11      1.0
# age_of_policyholder      0.55      1.0
# population_density   27003.00  73430.0
# is_claim                 0.00      1.0

# %% [markdown]
# 3) Data type and Missing values

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58515 entries, 0 to 58514
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         58515 non-null  object
#  1   make                              58515 non-null  int64
#  2   segment                           58515 non-null  object
#  3   model                             58515 non-null  object
#  4   fuel_type                         58489 non-null  object
#  5   max_torque                        58508 non-null  object
#  6   max_power                         58512 non-null  object
#  7   engine_type                       58512 non-null  object
#  8   airbags                           58506 non-null  float64
#  9   is_esc                            58512 non-null  object
#  10  is_adjustable_steering            58508 non-null  object
#  11  is_tpms                           58512 non-null  object
#  12  is_parking_sensors                58508 non-null  object
#  13  is_parking_camera                 58512 non-null  object
#  14  rear_brakes_type                  58515 non-null  object
#  15  displacement                      58508 non-null  float64
#  16  cylinder                          58508 non-null  float64
#  17  transmission_type                 58515 non-null  object
#  18  gear_box                          58515 non-null  int64
#  19  steering_type                     58515 non-null  object
#  20  turning_radius                    58515 non-null  float64
#  21  length                            58515 non-null  int64
#  22  width                             58515 non-null  int64
#  23  height                            58515 non-null  int64
#  24  gross_weight                      58515 non-null  int64
#  25  is_front_fog_lights               58515 non-null  object
#  26  is_rear_window_wiper              58515 non-null  object
#  27  is_rear_window_washer             58515 non-null  object
#  28  is_rear_window_defogger           58515 non-null  object
#  29  is_brake_assist                   58515 non-null  object
#  30  is_power_door_locks               58515 non-null  object
#  31  is_central_locking                58515 non-null  object
#  32  is_power_steering                 58515 non-null  object
#  33  is_driver_seat_height_adjustable  58515 non-null  object
#  34  is_day_night_rear_view_mirror     58515 non-null  object
#  35  is_ecw                            58515 non-null  object
#  36  is_speed_alert                    58515 non-null  object
#  37  ncap_rating                       58515 non-null  int64
#  38  policy_tenure                     58495 non-null  float64
#  39  age_of_car                        58510 non-null  float64
#  40  age_of_policyholder               58508 non-null  float64
#  41  area_cluster                      58509 non-null  object
#  42  population_density                58503 non-null  float64
#  43  is_claim                          58515 non-null  int64
# dtypes: float64(8), int64(8), object(28)
# memory usage: 19.6+ MB

# %% [markdown]
# Missing Values

# %%
print(final_data.isnull().sum())
# Out:
# policy_id                            0
# make                                 0
# segment                              0
# model                                0
# fuel_type                           26
# max_torque                           7
# max_power                            3
# engine_type                          3
# airbags                              9
# is_esc                               3
# is_adjustable_steering               7
# is_tpms                              3
# is_parking_sensors                   7
# is_parking_camera                    3
# rear_brakes_type                     0
# displacement                         7
# cylinder                             7
# transmission_type                    0
# gear_box                             0
# steering_type                        0
# turning_radius                       0
# length                               0
# width                                0
# height                               0
# gross_weight                         0
# is_front_fog_lights                  0
# is_rear_window_wiper                 0
# is_rear_window_washer                0
# is_rear_window_defogger              0
# is_brake_assist                      0
# is_power_door_locks                  0
# is_central_locking                   0
# is_power_steering                    0
# is_driver_seat_height_adjustable     0
# is_day_night_rear_view_mirror        0
# is_ecw                               0
# is_speed_alert                       0
# ncap_rating                          0
# policy_tenure                       20
# age_of_car                           5
# age_of_policyholder                  7
# area_cluster                         6
# population_density                  12
# is_claim                             0
# dtype: int64
